# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True)
# Out:
# True

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # this must run BEFORE you call os.getenv

print(os.getenv("OPENROUTER_API_KEY"))  # sanity check - should print your key, not None
# Out:
# None
